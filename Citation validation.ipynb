# %%
from nltk.tokenize import sent_tokenize
import requests
from bs4 import BeautifulSoup as bs #Thats some bs!!!
import re#
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

# %%
#get unique case links
#All links
opinion = requests.get("https://scholar.google.com/scholar_case?case=9151214196953452755&q=ARTIFICIAL&hl=en&scisbd=2&as_sdt=4,176")
soup = bs(opinion.content, 'html.parser')

all_links = soup.select('a') #everything tag with a link in it
all_urls = [link['href'] for link in all_links] # just the links

def just_case_links(a): #removing non-case links
    pattern = re.compile(r'scholar_case\?case') #pattern that only in case links that I have access to
    matches = pattern.findall(a) 
    for match in matches: #This is the only way I know how to do this in regex. And I'm sorry. 
        return match #Matches will be a string match or None

case_links = [] #All the cases 
for i in all_urls:
    if type(just_case_links(i)) == str: #Filtering so that only matches are returned 
        case_links.append(i)
#print(case_links) # checking mah work

unique_case_links = [] #Making unique case lists - not sure if I need this
for i in case_links:
    if i not in unique_case_links:
        unique_case_links.append(i) #appending stuff in a for loop is my jam. 

for i in unique_case_links:
    i = "https://scholar.google.com" + i
    print(i)
# Out:
# https://scholar.google.com/scholar_case?case=8874361302650918036&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176
# https://scholar.google.com/scholar_case?case=2777200121617936111&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176
# https://scholar.google.com/scholar_case?case=5842887385729421133&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176
# https://scholar.google.com/scholar_case?case=15991983770421640378&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176
# https://scholar.google.com/scholar_case?case=1508908812310504849&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176
# https://scholar.google.com/scholar_case?case=8059952625725125823&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176
# https://scholar.google.com/scholar_case?case=16570622699951746078&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176
# https://scholar.google.com/scholar_case?case=17989060472750424778&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176
# https://scholar.google.com/scholar_case?case=14285288713033218770&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176
# ...

# %%
#MAKING A COUNTER
counting_citations = {}
for case in case_links:
    counting_citations[case] = counting_citations.get(case, 0) + 1 #This counts all the URLS? 

#ADD Id. Citations - Basically, Id. is just +1 to the previous citation. 
#Id. 

italics = soup.find_all('i')
ids_list = []
for i in italics: 
    if "Id." in i:
        ids_list.append(i) 
print(ids_list)
print(len(ids_list))

#Here is a problem with just looking for italic Id. They are not linked. 
# Id. can refer to a caselaw citation, but also a statute, regulation, Amendment etc. In most cases, it will be a case..
#Before doing this it might be good to webscrape as much law as I can find. 

#I won't be able to make this accurate without first knowing what the statutes are. Not linked in any free caselaw generator
#Exception is casetext. But there is a provision where they get my IP if I use their website. The fuck? 

#https://www.law.cornell.edu/uscode/text - Scrape from here to get all U.S. / state statutes, admin regulations, etc. 
#Should be able to get almost all law that is current. Might have difficulty if law is outdated. 
#It won't have municipal ordinances, or local court rules, or something similar. 

#Other option is to make a regex object. God that sounds awful. 

#From there, match from list of statutes. 
#



#ids_list = [ids_list.append(i) for i in italics if "Id." in i] hmm y this no work
# Out:
# [<i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>, <i>Id.</i>]
# 16

# %%
#get unique case links
#All links
opinion = requests.get("https://scholar.google.com/scholar_case?case=9151214196953452755&q=ARTIFICIAL&hl=en&scisbd=2&as_sdt=4,176")
soup = bs(opinion.content, 'html.parser')

all_links = soup.select('a') #everything tag with a link in it
all_urls = [link['href'] for link in all_links] # just the links

def just_case_links(a): #removing non-case links
    pattern = re.compile(r'scholar_case\?case') #pattern that only in case links that I have access to
    matches = pattern.findall(a) 
    for match in matches: #This is the only way I know how to do this in regex. And I'm sorry. 
        return match #Matches will be a string match or None

case_links = [] #All the cases 
for i in all_urls:
    if type(just_case_links(i)) == str: #Filtering so that only matches are returned 
        case_links.append(i)
#print(case_links) # checking mah work

unique_case_links = [] #Making unique case lists - not sure if I need this
for i in case_links:
    if i not in unique_case_links:
        unique_case_links.append() #appending stuff in a for loop is my jam. 
print(unique_case_links)
# Out:
# ['/scholar_case?case=8874361302650918036&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=2777200121617936111&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=5842887385729421133&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=15991983770421640378&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=1508908812310504849&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=8059952625725125823&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=16570622699951746078&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=17989060472750424778&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=14285288713033218770&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=7634193744317556282&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=13865744571649109803&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=8310794434138007399&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,17
# ...

# %%
# MATCH CITATIONS
print(some_list)


a_list = ['/scholar_case?case=13865744571649109803&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176',
'/scholar_case?case=4330902344630907045&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176']

some_string = '/scholar_case?case=13865744571649109803&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176'

string_all_links = [str(i) for i in all_links]

print(all_links[25])

#if some_string in string_all_links:
all_links = soup.select('a')
# Out:
# ['/scholar_case?case=14249747239977704660&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=1380475486423084828&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176', '/scholar_case?case=1380475486423084828&q=ARTIFICIAL&hl=en&oe=ASCII&as_sdt=4,176']
# yay
# woah
# <a class="gsl_pagenum2" href="#p80" id="p80">*80</a>
# ...

# %%
service = Service(executable_path='C:\\Users\\tchak\\OneDrive\\Desktop\\chromedriver.exe')
driver = webdriver.Chrome(service=service)

s=Service('C:\\Users\\tchak\\OneDrive\Desktop\\chromedriver.exe')

browser = webdriver.Chrome(service=s)
browser.get('https://www.law.cornell.edu/regulations/illinois')
print(browser.page_source)

#browser.quit
# Out:
# <html lang="en"><head><script type="text/javascript" src="https://m.addthis.com/live/red_lojson/300lo.json?si=61b7f3c912fd6b62&amp;bkl=0&amp;bl=1&amp;pdt=315&amp;sid=61b7f3c912fd6b62&amp;pub=liiadverts&amp;rev=v8.28.8-wp&amp;ln=en&amp;pc=men&amp;cb=0&amp;ab=-&amp;dp=www.law.cornell.edu&amp;fp=state_regulations%2Fillinois.html&amp;fr=&amp;of=0&amp;pd=0&amp;irt=0&amp;vcl=0&amp;md=0&amp;ct=1&amp;tct=0&amp;abt=0&amp;cdn=0&amp;pi=1&amp;rb=0&amp;gen=100&amp;chr=UTF-8&amp;colc=1639445450204&amp;jsl=1&amp;uvs=61b7f3c91011c516000&amp;skipb=1&amp;callback=addthis.cbs.jsonp__0093349114164882340"></script><script type="text/javascript" src="https://v1.addthisedge.com/live/boost/liiadverts/_ate.track.config_resp"></script><script src="https://partner.googleadservices.com/gampad/cookie.js?domain=www.law.cornell.edu&amp;callback=_gfp_s_&amp;client=ca-pub-6351434937294517"></script><script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202112060101/show_ads_impl_fy2019.js" id=
# ...
